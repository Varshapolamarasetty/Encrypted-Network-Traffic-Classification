# %%
# ------------------------------
# 1. Import libraries
# ------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score

# ------------------------------
# 2. Load dataset
# ------------------------------
df = pd.read_csv("/content/vpn_nonvpn_reconstructed.csv")

# ------------------------------
# 3. Encode target labels
# ------------------------------
le = LabelEncoder()
df['class1'] = le.fit_transform(df['class1'])
num_classes = df['class1'].nunique()

# ------------------------------
# 4. Define features & target
# ------------------------------
feature_order = [
    "duration",
    "min_fiat","mean_fiat","max_fiat",
    "min_biat","mean_biat","max_biat",
    "min_flowiat","mean_flowiat","max_flowiat","std_flowiat",
    "flowPktsPerSecond","flowBytesPerSecond",
    "min_active","mean_active","max_active","std_active",
    "min_idle","mean_idle","max_idle","std_idle",
    "total_fiat","total_biat"
]

X = df[feature_order]
y = df['class1']

# ------------------------------
# 5. Train-test split
# ------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# ------------------------------
# 6. Apply SMOTE (training only)
# ------------------------------
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# ------------------------------
# 7. Build XGBoost model
# ------------------------------
xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='multi:softprob' if num_classes > 2 else 'binary:logistic',
    num_class=num_classes if num_classes > 2 else None,
    eval_metric='mlogloss',
    random_state=42,
    n_jobs=-1
)

# ------------------------------
# 8. Train model
# ------------------------------
xgb_model.fit(X_train, y_train)

# ------------------------------
# 9. Evaluate model
# ------------------------------
y_pred = xgb_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"\nTest Accuracy: {accuracy:.4f}")

# ------------------------------
# 10. Classification report
# ------------------------------
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Test Accuracy: 0.9552
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing       0.98      0.97      0.98       500
#          chat       0.79      0.91      0.85       178
#            ft       0.94      0.91      0.92       204
#          mail       0.69      0.84      0.76        50
#           p2p       0.99      0.97      0.98       200
#     streaming       0.95      0.90      0.92        96
#          voip       1.00      1.00      1.00       565
#  vpn-browsing       0.94      0.93      0.93       500
#      vpn-chat       0.94      0.93      0.94       239
#        vpn-ft       0.95      0.94      0.94       387
#      vpn-mail       0.92      0.90      0.91        98
#       vpn-p2p       1.00      0.99      1.00       186
# vpn-streaming       0.97      0.96      0.96        95
#      vpn-voip       0.99      0.99      0.99       454
#
#      accuracy                           0.96      3752
#     macro avg       0.93      0.94      0.93      3752
#  weighted avg       0.96      0.96      0.96      3752

# %%
# ------------------------------
# 1. Import libraries
# ------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# ------------------------------
# 2. Load dataset
# ------------------------------
df = pd.read_csv("/content/vpn_nonvpn_reconstructed.csv")

# ------------------------------
# 3. Encode target labels
# ------------------------------
le = LabelEncoder()
df['class1'] = le.fit_transform(df['class1'])
num_classes = df['class1'].nunique()

# ------------------------------
# 4. Define features & target
# ------------------------------
feature_order = [
    "duration",
    "min_fiat","mean_fiat","max_fiat",
    "min_biat","mean_biat","max_biat",
    "min_flowiat","mean_flowiat","max_flowiat","std_flowiat",
    "flowPktsPerSecond","flowBytesPerSecond",
    "min_active","mean_active","max_active","std_active",
    "min_idle","mean_idle","max_idle","std_idle",
    "total_fiat","total_biat"
]

X = df[feature_order]
y = df['class1']

# ------------------------------
# 5. Train-test split
# ------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# ------------------------------
# 6. Apply SMOTE (training only)
# ------------------------------
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# ------------------------------
# 7. Build Random Forest model
# ------------------------------
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=20,
    min_samples_split=5,
    min_samples_leaf=2,
    max_features='sqrt',
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

# ------------------------------
# 8. Train model
# ------------------------------
rf_model.fit(X_train, y_train)

# ------------------------------
# 9. Evaluate model
# ------------------------------
y_pred = rf_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"\nTest Accuracy: {accuracy:.4f}")

# ------------------------------
# 10. Classification report
# ------------------------------
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Test Accuracy: 0.9064
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing       0.93      0.95      0.94       500
#          chat       0.71      0.72      0.72       178
#            ft       0.85      0.85      0.85       204
#          mail       0.67      0.80      0.73        50
#           p2p       0.98      0.97      0.98       200
#     streaming       0.95      0.76      0.84        96
#          voip       1.00      1.00      1.00       565
#  vpn-browsing       0.85      0.86      0.85       500
#      vpn-chat       0.83      0.81      0.82       239
#        vpn-ft       0.84      0.84      0.84       387
#      vpn-mail       0.95      0.85      0.90        98
#       vpn-p2p       1.00      0.99      1.00       186
# vpn-streaming       0.86      0.91      0.88        95
#      vpn-voip       0.99      0.99      0.99       454
#
#      accuracy                           0.91      3752
#     macro avg       0.89      0.88      0.88      3752
#  weighted avg       0.91      0.91      0.91      3752

# %%
# ------------------------------
# 1. Import libraries
# ------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report

# ------------------------------
# 2. Load dataset
# ------------------------------
df = pd.read_csv("/content/vpn_nonvpn_reconstructed.csv")

# ------------------------------
# 3. Encode target labels
# ------------------------------
le = LabelEncoder()
df['class1'] = le.fit_transform(df['class1'])
num_classes = df['class1'].nunique()

# ------------------------------
# 4. Define features & target
# ------------------------------
feature_order = [
    "duration",
    "min_fiat","mean_fiat","max_fiat",
    "min_biat","mean_biat","max_biat",
    "min_flowiat","mean_flowiat","max_flowiat","std_flowiat",
    "flowPktsPerSecond","flowBytesPerSecond",
    "min_active","mean_active","max_active","std_active",
    "min_idle","mean_idle","max_idle","std_idle",
    "total_fiat","total_biat"
]

X = df[feature_order]
y = df['class1']

# ------------------------------
# 5. Train-test split
# ------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# ------------------------------
# 6. Apply SMOTE only on training data
# ------------------------------
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# ------------------------------
# 7. Scale features
# ------------------------------
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# ------------------------------
# 8. Reshape for CNN
# ------------------------------
X_train_cnn = X_train_scaled.reshape(-1, X_train_scaled.shape[1], 1)
X_test_cnn  = X_test_scaled.reshape(-1, X_test_scaled.shape[1], 1)
num_features = X_train_cnn.shape[1]

# ------------------------------
# 9. Build optimized CNN model
# ------------------------------
cnn_model = Sequential([
    Input(shape=(num_features,1)),

    Conv1D(64, 3, padding='same'),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),

    Conv1D(128, 3, padding='same'),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(256, 3, padding='same'),
    LeakyReLU(alpha=0.1),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    GlobalMaxPooling1D(),

    Dense(128),
    LeakyReLU(alpha=0.1),
    Dropout(0.15),

    Dense(num_classes, activation='softmax')
])

# ------------------------------
# 10. Compile model
# ------------------------------
cnn_model.compile(
    optimizer=Adam(learning_rate=0.0002),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ------------------------------
# 11. Callbacks
# ------------------------------
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
]

# ------------------------------
# 12. Train model
# ------------------------------
history = cnn_model.fit(
    X_train_cnn, y_train,
    validation_data=(X_test_cnn, y_test),
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
    verbose=2
)

# ------------------------------
# 13. Evaluate model
# ------------------------------
loss, accuracy = cnn_model.evaluate(X_test_cnn, y_test)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# ------------------------------
# 14. Classification report
# ------------------------------
y_pred_prob = cnn_model.predict(X_test_cnn)
y_pred = np.argmax(y_pred_prob, axis=1)

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/200
# 495/495 - 20s - 41ms/step - accuracy: 0.5151 - loss: 1.5336 - val_accuracy: 0.5728 - val_loss: 1.3050 - learning_rate: 2.0000e-04
# Epoch 2/200
# 495/495 - 16s - 33ms/step - accuracy: 0.7331 - loss: 0.8217 - val_accuracy: 0.7340 - val_loss: 0.7851 - learning_rate: 2.0000e-04
# Epoch 3/200
# 495/495 - 18s - 36ms/step - accuracy: 0.8073 - loss: 0.5925 - val_accuracy: 0.7711 - val_loss: 0.6879 - learning_rate: 2.0000e-04
# Epoch 4/200
# 495/495 - 16s - 33ms/step - accuracy: 0.8490 - loss: 0.4623 - val_accuracy: 0.7894 - val_loss: 0.6245 - learning_rate: 2.0000e-04
# Epoch 5/200
# 495/495 - 21s - 43ms/step - accuracy: 0.8745 - loss: 0.3804 - val_accuracy: 0.8033 - val_loss: 0.5955 - learning_rate: 2.0000e-04
# Epoch 6/200
# 495/495 - 20s - 40ms/step - accuracy: 0.8933 - loss: 0.3200 - val_accuracy: 0.7942 - val_loss: 0.6173 - learning_rate: 2.0000e-04
# Epoch 7/200
# 495/495 - 17s - 33ms/step - accuracy: 0.9116 - loss: 0.2750 - val_accuracy: 0.8148 - val_loss: 0.5841 - learning_rate: 2.0000e-04
# Epoch 8/200
# 495/495 - 18s - 35ms/step - accuracy: 0.9187 - loss: 0.2451 - val_accuracy: 0.8161 - val_loss: 0.5548 - learning_rate: 2.0000e-04
# Epoch 9/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9299 - loss: 0.2153 - val_accuracy: 0.8260 - val_loss: 0.5715 - learning_rate: 2.0000e-04
# Epoch 10/200
# 495/495 - 20s - 41ms/step - accuracy: 0.9382 - loss: 0.1893 - val_accuracy: 0.8236 - val_loss: 0.5692 - learning_rate: 2.0000e-04
# Epoch 11/200
# 495/495 - 18s - 36ms/step - accuracy: 0.9453 - loss: 0.1695 - val_accuracy: 0.8204 - val_loss: 0.5760 - learning_rate: 2.0000e-04
# Epoch 12/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9505 - loss: 0.1530 - val_accuracy: 0.8350 - val_loss: 0.5519 - learning_rate: 2.0000e-04
# Epoch 13/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9546 - loss: 0.1396 - val_accuracy: 0.8414 - val_loss: 0.5240 - learning_rate: 2.0000e-04
# Epoch 14/200
# 495/495 - 17s - 34ms/step - accuracy: 0.9579 - loss: 0.1282 - val_accuracy: 0.8385 - val_loss: 0.5640 - learning_rate: 2.0000e-04
# Epoch 15/200
# 495/495 - 17s - 35ms/step - accuracy: 0.9611 - loss: 0.1198 - val_accuracy: 0.8505 - val_loss: 0.5131 - learning_rate: 2.0000e-04
# Epoch 16/200
# 495/495 - 20s - 40ms/step - accuracy: 0.9641 - loss: 0.1086 - val_accuracy: 0.8467 - val_loss: 0.5542 - learning_rate: 2.0000e-04
# Epoch 17/200
# 495/495 - 18s - 35ms/step - accuracy: 0.9670 - loss: 0.0974 - val_accuracy: 0.8443 - val_loss: 0.5508 - learning_rate: 2.0000e-04
# Epoch 18/200
# 495/495 - 19s - 39ms/step - accuracy: 0.9707 - loss: 0.0895 - val_accuracy: 0.8507 - val_loss: 0.5281 - learning_rate: 2.0000e-04
# Epoch 19/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9736 - loss: 0.0795 - val_accuracy: 0.8497 - val_loss: 0.5786 - learning_rate: 2.0000e-04
# Epoch 20/200
# 495/495 - 18s - 36ms/step - accuracy: 0.9718 - loss: 0.0854 - val_accuracy: 0.8515 - val_loss: 0.5581 - learning_rate: 2.0000e-04
# Epoch 21/200
# 495/495 - 19s - 39ms/step - accuracy: 0.9888 - loss: 0.0416 - val_accuracy: 0.8678 - val_loss: 0.4997 - learning_rate: 4.0000e-05
# Epoch 22/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9923 - loss: 0.0307 - val_accuracy: 0.8710 - val_loss: 0.4999 - learning_rate: 4.0000e-05
# Epoch 23/200
# 495/495 - 18s - 36ms/step - accuracy: 0.9940 - loss: 0.0262 - val_accuracy: 0.8721 - val_loss: 0.4992 - learning_rate: 4.0000e-05
# Epoch 24/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9938 - loss: 0.0251 - val_accuracy: 0.8734 - val_loss: 0.5096 - learning_rate: 4.0000e-05
# Epoch 25/200
# 495/495 - 21s - 43ms/step - accuracy: 0.9943 - loss: 0.0230 - val_accuracy: 0.8715 - val_loss: 0.5091 - learning_rate: 4.0000e-05
# Epoch 26/200
# 495/495 - 17s - 34ms/step - accuracy: 0.9948 - loss: 0.0226 - val_accuracy: 0.8702 - val_loss: 0.5210 - learning_rate: 4.0000e-05
# Epoch 27/200
# 495/495 - 20s - 40ms/step - accuracy: 0.9949 - loss: 0.0215 - val_accuracy: 0.8702 - val_loss: 0.5116 - learning_rate: 4.0000e-05
# Epoch 28/200
# 495/495 - 18s - 37ms/step - accuracy: 0.9957 - loss: 0.0198 - val_accuracy: 0.8699 - val_loss: 0.5354 - learning_rate: 4.0000e-05
# Epoch 29/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9966 - loss: 0.0167 - val_accuracy: 0.8731 - val_loss: 0.5203 - learning_rate: 8.0000e-06
# Epoch 30/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9968 - loss: 0.0154 - val_accuracy: 0.8721 - val_loss: 0.5201 - learning_rate: 8.0000e-06
# Epoch 31/200
# 495/495 - 17s - 33ms/step - accuracy: 0.9971 - loss: 0.0151 - val_accuracy: 0.8710 - val_loss: 0.5211 - learning_rate: 8.0000e-06
# Epoch 32/200
# 495/495 - 18s - 36ms/step - accuracy: 0.9973 - loss: 0.0147 - val_accuracy: 0.8710 - val_loss: 0.5222 - learning_rate: 8.0000e-06
# Epoch 33/200
# 495/495 - 19s - 39ms/step - accuracy: 0.9977 - loss: 0.0140 - val_accuracy: 0.8723 - val_loss: 0.5224 - learning_rate: 8.0000e-06
# Epoch 34/200
# 495/495 - 21s - 42ms/step - accuracy: 0.9979 - loss: 0.0131 - val_accuracy: 0.8734 - val_loss: 0.5238 - learning_rate: 1.6000e-06
# Epoch 35/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9978 - loss: 0.0128 - val_accuracy: 0.8729 - val_loss: 0.5232 - learning_rate: 1.6000e-06
# Epoch 36/200
# 495/495 - 22s - 44ms/step - accuracy: 0.9973 - loss: 0.0132 - val_accuracy: 0.8721 - val_loss: 0.5225 - learning_rate: 1.6000e-06
# Epoch 37/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9972 - loss: 0.0138 - val_accuracy: 0.8726 - val_loss: 0.5216 - learning_rate: 1.6000e-06
# Epoch 38/200
# 495/495 - 16s - 33ms/step - accuracy: 0.9975 - loss: 0.0135 - val_accuracy: 0.8721 - val_loss: 0.5218 - learning_rate: 1.6000e-06
# Epoch 39/200
# 495/495 - 17s - 34ms/step - accuracy: 0.9981 - loss: 0.0125 - val_accuracy: 0.8731 - val_loss: 0.5231 - learning_rate: 1.0000e-06
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8840 - loss: 0.4627
#
# Test Loss: 0.5096
# Test Accuracy: 0.8734
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing       0.94      0.96      0.95       500
#          chat       0.75      0.72      0.74       178
#            ft       0.85      0.78      0.82       204
#          mail       0.67      0.60      0.63        50
#           p2p       0.94      0.94      0.94       200
#     streaming       0.82      0.64      0.72        96
#          voip       1.00      1.00      1.00       565
#  vpn-browsing       0.80      0.87      0.83       500
#      vpn-chat       0.65      0.66      0.66       239
#        vpn-ft       0.74      0.75      0.74       387
#      vpn-mail       0.85      0.72      0.78        98
#       vpn-p2p       0.98      0.99      0.99       186
# vpn-streaming       0.84      0.83      0.84        95
#      vpn-voip       0.99      0.99      0.99       454
#
#      accuracy                           0.87      3752
#     macro avg       0.84      0.82      0.83      3752
#  weighted avg       0.87      0.87      0.87      3752

# %%
# ------------------------------
# 1. Import libraries
# ------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report

# ------------------------------
# 2. Load dataset
# ------------------------------
df = pd.read_csv("/content/vpn_nonvpn_reconstructed.csv")

# ------------------------------
# 3. Encode target labels
# ------------------------------
le = LabelEncoder()
df['class1'] = le.fit_transform(df['class1'])
num_classes = df['class1'].nunique()

# ------------------------------
# 4. Define features & target
# ------------------------------
feature_order = [
    "duration",
    "min_fiat","mean_fiat","max_fiat",
    "min_biat","mean_biat","max_biat",
    "min_flowiat","mean_flowiat","max_flowiat","std_flowiat",
    "flowPktsPerSecond","flowBytesPerSecond",
    "min_active","mean_active","max_active","std_active",
    "min_idle","mean_idle","max_idle","std_idle",
    "total_fiat","total_biat"
]

X = df[feature_order]
y = df['class1']

# ------------------------------
# 5. Train-test split
# ------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# ------------------------------
# 6. Apply SMOTE only on training data
# ------------------------------
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# ------------------------------
# 7. Scale features
# ------------------------------
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# ------------------------------
# 8. Reshape for LSTM
# ------------------------------
# LSTM expects: (samples, timesteps, features)
X_train_lstm = X_train_scaled.reshape(-1, X_train_scaled.shape[1], 1)
X_test_lstm  = X_test_scaled.reshape(-1, X_test_scaled.shape[1], 1)

timesteps = X_train_lstm.shape[1]

# ------------------------------
# 9. Build optimized LSTM model
# ------------------------------
lstm_model = Sequential([
    Input(shape=(timesteps, 1)),

    LSTM(128, return_sequences=True),
    BatchNormalization(),
    Dropout(0.3),

    LSTM(64),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    Dropout(0.2),

    Dense(num_classes, activation='softmax')
])

# ------------------------------
# 10. Compile model
# ------------------------------
lstm_model.compile(
    optimizer=Adam(learning_rate=0.0003),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ------------------------------
# 11. Callbacks
# ------------------------------
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
]

# ------------------------------
# 12. Train model
# ------------------------------
history = lstm_model.fit(
    X_train_lstm, y_train,
    validation_data=(X_test_lstm, y_test),
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
    verbose=2
)

# ------------------------------
# 13. Evaluate model
# ------------------------------
loss, accuracy = lstm_model.evaluate(X_test_lstm, y_test)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# ------------------------------
# 14. Classification report
# ------------------------------
y_pred_prob = lstm_model.predict(X_test_lstm)
y_pred = np.argmax(y_pred_prob, axis=1)

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Epoch 1/200
# 495/495 - 42s - 86ms/step - accuracy: 0.1653 - loss: 2.5478 - val_accuracy: 0.2969 - val_loss: 2.2584 - learning_rate: 3.0000e-04
# Epoch 2/200
# 495/495 - 39s - 78ms/step - accuracy: 0.2307 - loss: 2.2764 - val_accuracy: 0.3105 - val_loss: 2.0068 - learning_rate: 3.0000e-04
# Epoch 3/200
# 495/495 - 38s - 76ms/step - accuracy: 0.2873 - loss: 2.0970 - val_accuracy: 0.4080 - val_loss: 1.7300 - learning_rate: 3.0000e-04
# Epoch 4/200
# 495/495 - 37s - 75ms/step - accuracy: 0.3389 - loss: 1.9491 - val_accuracy: 0.4395 - val_loss: 1.6582 - learning_rate: 3.0000e-04
# Epoch 5/200
# 495/495 - 36s - 73ms/step - accuracy: 0.3828 - loss: 1.8168 - val_accuracy: 0.4638 - val_loss: 1.5266 - learning_rate: 3.0000e-04
# Epoch 6/200
# 495/495 - 37s - 76ms/step - accuracy: 0.4229 - loss: 1.6942 - val_accuracy: 0.5059 - val_loss: 1.4149 - learning_rate: 3.0000e-04
# Epoch 7/200
# 495/495 - 41s - 83ms/step - accuracy: 0.4587 - loss: 1.5870 - val_accuracy: 0.5429 - val_loss: 1.3243 - learning_rate: 3.0000e-04
# Epoch 8/200
# 495/495 - 38s - 76ms/step - accuracy: 0.4920 - loss: 1.4893 - val_accuracy: 0.5466 - val_loss: 1.2500 - learning_rate: 3.0000e-04
# Epoch 9/200
# 495/495 - 39s - 78ms/step - accuracy: 0.5212 - loss: 1.4056 - val_accuracy: 0.5706 - val_loss: 1.1990 - learning_rate: 3.0000e-04
# Epoch 10/200
# 495/495 - 39s - 78ms/step - accuracy: 0.5421 - loss: 1.3334 - val_accuracy: 0.5896 - val_loss: 1.1582 - learning_rate: 3.0000e-04
# Epoch 11/200
# 495/495 - 38s - 77ms/step - accuracy: 0.5606 - loss: 1.2798 - val_accuracy: 0.5920 - val_loss: 1.1321 - learning_rate: 3.0000e-04
# Epoch 12/200
# 495/495 - 36s - 73ms/step - accuracy: 0.5811 - loss: 1.2209 - val_accuracy: 0.6002 - val_loss: 1.1205 - learning_rate: 3.0000e-04
# Epoch 13/200
# 495/495 - 37s - 75ms/step - accuracy: 0.5977 - loss: 1.1723 - val_accuracy: 0.6098 - val_loss: 1.0849 - learning_rate: 3.0000e-04
# Epoch 14/200
# 495/495 - 37s - 76ms/step - accuracy: 0.6139 - loss: 1.1265 - val_accuracy: 0.6181 - val_loss: 1.0500 - learning_rate: 3.0000e-04
# Epoch 15/200
# 495/495 - 38s - 76ms/step - accuracy: 0.6255 - loss: 1.0842 - val_accuracy: 0.6277 - val_loss: 1.0096 - learning_rate: 3.0000e-04
# Epoch 16/200
# 495/495 - 37s - 76ms/step - accuracy: 0.6340 - loss: 1.0566 - val_accuracy: 0.6383 - val_loss: 0.9977 - learning_rate: 3.0000e-04
# Epoch 17/200
# 495/495 - 36s - 73ms/step - accuracy: 0.6470 - loss: 1.0181 - val_accuracy: 0.6469 - val_loss: 0.9843 - learning_rate: 3.0000e-04
# Epoch 18/200
# 495/495 - 42s - 86ms/step - accuracy: 0.6566 - loss: 0.9853 - val_accuracy: 0.6511 - val_loss: 0.9513 - learning_rate: 3.0000e-04
# Epoch 19/200
# 495/495 - 36s - 73ms/step - accuracy: 0.6694 - loss: 0.9518 - val_accuracy: 0.6612 - val_loss: 0.9216 - learning_rate: 3.0000e-04
# Epoch 20/200
# 495/495 - 39s - 78ms/step - accuracy: 0.6792 - loss: 0.9189 - val_accuracy: 0.6738 - val_loss: 0.9146 - learning_rate: 3.0000e-04
# Epoch 21/200
# 495/495 - 39s - 78ms/step - accuracy: 0.6852 - loss: 0.9028 - val_accuracy: 0.6748 - val_loss: 0.9052 - learning_rate: 3.0000e-04
# Epoch 22/200
# 495/495 - 37s - 76ms/step - accuracy: 0.6982 - loss: 0.8836 - val_accuracy: 0.6900 - val_loss: 0.8733 - learning_rate: 3.0000e-04
# Epoch 23/200
# 495/495 - 41s - 83ms/step - accuracy: 0.7048 - loss: 0.8535 - val_accuracy: 0.6962 - val_loss: 0.8483 - learning_rate: 3.0000e-04
# Epoch 24/200
# 495/495 - 41s - 82ms/step - accuracy: 0.7117 - loss: 0.8358 - val_accuracy: 0.6906 - val_loss: 0.8706 - learning_rate: 3.0000e-04
# Epoch 25/200
# 495/495 - 37s - 76ms/step - accuracy: 0.7214 - loss: 0.8030 - val_accuracy: 0.7122 - val_loss: 0.8002 - learning_rate: 3.0000e-04
# Epoch 26/200
# 495/495 - 37s - 75ms/step - accuracy: 0.7305 - loss: 0.7813 - val_accuracy: 0.7036 - val_loss: 0.8254 - learning_rate: 3.0000e-04
# Epoch 27/200
# 495/495 - 37s - 75ms/step - accuracy: 0.7377 - loss: 0.7629 - val_accuracy: 0.7130 - val_loss: 0.8059 - learning_rate: 3.0000e-04
# Epoch 28/200
# 495/495 - 41s - 83ms/step - accuracy: 0.7438 - loss: 0.7466 - val_accuracy: 0.7162 - val_loss: 0.7983 - learning_rate: 3.0000e-04
# Epoch 29/200
# 495/495 - 42s - 85ms/step - accuracy: 0.7482 - loss: 0.7296 - val_accuracy: 0.7188 - val_loss: 0.7892 - learning_rate: 3.0000e-04
# Epoch 30/200
# 495/495 - 40s - 80ms/step - accuracy: 0.7548 - loss: 0.7112 - val_accuracy: 0.7281 - val_loss: 0.7850 - learning_rate: 3.0000e-04
# Epoch 31/200
# 495/495 - 37s - 76ms/step - accuracy: 0.7616 - loss: 0.6927 - val_accuracy: 0.7276 - val_loss: 0.7681 - learning_rate: 3.0000e-04
# Epoch 32/200
# 495/495 - 37s - 74ms/step - accuracy: 0.7647 - loss: 0.6806 - val_accuracy: 0.7313 - val_loss: 0.7536 - learning_rate: 3.0000e-04
# Epoch 33/200
# 495/495 - 36s - 73ms/step - accuracy: 0.7725 - loss: 0.6661 - val_accuracy: 0.7433 - val_loss: 0.7374 - learning_rate: 3.0000e-04
# Epoch 34/200
# 495/495 - 37s - 76ms/step - accuracy: 0.7753 - loss: 0.6576 - val_accuracy: 0.7409 - val_loss: 0.7258 - learning_rate: 3.0000e-04
# Epoch 35/200
# 495/495 - 37s - 75ms/step - accuracy: 0.7809 - loss: 0.6312 - val_accuracy: 0.7540 - val_loss: 0.7205 - learning_rate: 3.0000e-04
# Epoch 36/200
# 495/495 - 37s - 76ms/step - accuracy: 0.7862 - loss: 0.6227 - val_accuracy: 0.7468 - val_loss: 0.7274 - learning_rate: 3.0000e-04
# Epoch 37/200
# 495/495 - 36s - 73ms/step - accuracy: 0.7946 - loss: 0.6058 - val_accuracy: 0.7599 - val_loss: 0.7103 - learning_rate: 3.0000e-04
# Epoch 38/200
# 495/495 - 37s - 74ms/step - accuracy: 0.7964 - loss: 0.5974 - val_accuracy: 0.7569 - val_loss: 0.7009 - learning_rate: 3.0000e-04
# Epoch 39/200
# 495/495 - 37s - 75ms/step - accuracy: 0.7996 - loss: 0.5863 - val_accuracy: 0.7657 - val_loss: 0.7001 - learning_rate: 3.0000e-04
# Epoch 40/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8037 - loss: 0.5699 - val_accuracy: 0.7567 - val_loss: 0.7112 - learning_rate: 3.0000e-04
# Epoch 41/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8082 - loss: 0.5601 - val_accuracy: 0.7663 - val_loss: 0.6972 - learning_rate: 3.0000e-04
# Epoch 42/200
# 495/495 - 36s - 73ms/step - accuracy: 0.8101 - loss: 0.5543 - val_accuracy: 0.7575 - val_loss: 0.6918 - learning_rate: 3.0000e-04
# Epoch 43/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8137 - loss: 0.5468 - val_accuracy: 0.7745 - val_loss: 0.6755 - learning_rate: 3.0000e-04
# Epoch 44/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8148 - loss: 0.5366 - val_accuracy: 0.7796 - val_loss: 0.6643 - learning_rate: 3.0000e-04
# Epoch 45/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8202 - loss: 0.5238 - val_accuracy: 0.7769 - val_loss: 0.6579 - learning_rate: 3.0000e-04
# Epoch 46/200
# 495/495 - 41s - 83ms/step - accuracy: 0.8242 - loss: 0.5129 - val_accuracy: 0.7801 - val_loss: 0.6626 - learning_rate: 3.0000e-04
# Epoch 47/200
# 495/495 - 41s - 82ms/step - accuracy: 0.8311 - loss: 0.4944 - val_accuracy: 0.7870 - val_loss: 0.6419 - learning_rate: 3.0000e-04
# Epoch 48/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8296 - loss: 0.4964 - val_accuracy: 0.7830 - val_loss: 0.6506 - learning_rate: 3.0000e-04
# Epoch 49/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8360 - loss: 0.4848 - val_accuracy: 0.7838 - val_loss: 0.6582 - learning_rate: 3.0000e-04
# Epoch 50/200
# 495/495 - 42s - 85ms/step - accuracy: 0.8367 - loss: 0.4783 - val_accuracy: 0.7865 - val_loss: 0.6393 - learning_rate: 3.0000e-04
# Epoch 51/200
# 495/495 - 37s - 74ms/step - accuracy: 0.8386 - loss: 0.4669 - val_accuracy: 0.7764 - val_loss: 0.6575 - learning_rate: 3.0000e-04
# Epoch 52/200
# 495/495 - 37s - 74ms/step - accuracy: 0.8425 - loss: 0.4607 - val_accuracy: 0.7921 - val_loss: 0.6306 - learning_rate: 3.0000e-04
# Epoch 53/200
# 495/495 - 40s - 82ms/step - accuracy: 0.8449 - loss: 0.4587 - val_accuracy: 0.7937 - val_loss: 0.6206 - learning_rate: 3.0000e-04
# Epoch 54/200
# 495/495 - 37s - 76ms/step - accuracy: 0.8479 - loss: 0.4500 - val_accuracy: 0.7950 - val_loss: 0.6188 - learning_rate: 3.0000e-04
# Epoch 55/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8505 - loss: 0.4405 - val_accuracy: 0.7980 - val_loss: 0.6174 - learning_rate: 3.0000e-04
# Epoch 56/200
# 495/495 - 41s - 83ms/step - accuracy: 0.8521 - loss: 0.4376 - val_accuracy: 0.7934 - val_loss: 0.6268 - learning_rate: 3.0000e-04
# Epoch 57/200
# 495/495 - 37s - 76ms/step - accuracy: 0.8519 - loss: 0.4266 - val_accuracy: 0.7972 - val_loss: 0.6202 - learning_rate: 3.0000e-04
# Epoch 58/200
# 495/495 - 38s - 76ms/step - accuracy: 0.8583 - loss: 0.4212 - val_accuracy: 0.8001 - val_loss: 0.6008 - learning_rate: 3.0000e-04
# Epoch 59/200
# 495/495 - 36s - 73ms/step - accuracy: 0.8588 - loss: 0.4089 - val_accuracy: 0.8054 - val_loss: 0.5990 - learning_rate: 3.0000e-04
# Epoch 60/200
# 495/495 - 37s - 76ms/step - accuracy: 0.8639 - loss: 0.4009 - val_accuracy: 0.8028 - val_loss: 0.6022 - learning_rate: 3.0000e-04
# Epoch 61/200
# 495/495 - 39s - 78ms/step - accuracy: 0.8662 - loss: 0.3931 - val_accuracy: 0.8030 - val_loss: 0.6055 - learning_rate: 3.0000e-04
# Epoch 62/200
# 495/495 - 39s - 78ms/step - accuracy: 0.8645 - loss: 0.3997 - val_accuracy: 0.8022 - val_loss: 0.6150 - learning_rate: 3.0000e-04
# Epoch 63/200
# 495/495 - 37s - 76ms/step - accuracy: 0.8651 - loss: 0.3980 - val_accuracy: 0.8126 - val_loss: 0.5931 - learning_rate: 3.0000e-04
# Epoch 64/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8706 - loss: 0.3789 - val_accuracy: 0.8124 - val_loss: 0.5704 - learning_rate: 3.0000e-04
# Epoch 65/200
# 495/495 - 36s - 72ms/step - accuracy: 0.8721 - loss: 0.3768 - val_accuracy: 0.8118 - val_loss: 0.5886 - learning_rate: 3.0000e-04
# Epoch 66/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8724 - loss: 0.3761 - val_accuracy: 0.8100 - val_loss: 0.6043 - learning_rate: 3.0000e-04
# Epoch 67/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8739 - loss: 0.3664 - val_accuracy: 0.8038 - val_loss: 0.6182 - learning_rate: 3.0000e-04
# Epoch 68/200
# 495/495 - 38s - 78ms/step - accuracy: 0.8763 - loss: 0.3611 - val_accuracy: 0.8166 - val_loss: 0.5701 - learning_rate: 3.0000e-04
# Epoch 69/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8782 - loss: 0.3590 - val_accuracy: 0.8172 - val_loss: 0.5885 - learning_rate: 3.0000e-04
# Epoch 70/200
# 495/495 - 36s - 73ms/step - accuracy: 0.8792 - loss: 0.3518 - val_accuracy: 0.8164 - val_loss: 0.5624 - learning_rate: 3.0000e-04
# Epoch 71/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8821 - loss: 0.3449 - val_accuracy: 0.8241 - val_loss: 0.5732 - learning_rate: 3.0000e-04
# Epoch 72/200
# 495/495 - 37s - 75ms/step - accuracy: 0.8837 - loss: 0.3450 - val_accuracy: 0.8212 - val_loss: 0.5686 - learning_rate: 3.0000e-04
# Epoch 73/200
# 495/495 - 41s - 83ms/step - accuracy: 0.8861 - loss: 0.3371 - val_accuracy: 0.8209 - val_loss: 0.5758 - learning_rate: 3.0000e-04
# Epoch 74/200
# 495/495 - 38s - 78ms/step - accuracy: 0.8882 - loss: 0.3290 - val_accuracy: 0.8214 - val_loss: 0.5873 - learning_rate: 3.0000e-04
# Epoch 75/200
# 495/495 - 38s - 78ms/step - accuracy: 0.8898 - loss: 0.3296 - val_accuracy: 0.8238 - val_loss: 0.5739 - learning_rate: 3.0000e-04
# Epoch 76/200
# 495/495 - 40s - 80ms/step - accuracy: 0.8962 - loss: 0.2963 - val_accuracy: 0.8289 - val_loss: 0.5529 - learning_rate: 6.0000e-05
# Epoch 77/200
# 495/495 - 37s - 75ms/step - accuracy: 0.9012 - loss: 0.2883 - val_accuracy: 0.8276 - val_loss: 0.5544 - learning_rate: 6.0000e-05
# Epoch 78/200
# 495/495 - 41s - 83ms/step - accuracy: 0.9042 - loss: 0.2820 - val_accuracy: 0.8270 - val_loss: 0.5518 - learning_rate: 6.0000e-05
# Epoch 79/200
# 495/495 - 37s - 75ms/step - accuracy: 0.9047 - loss: 0.2809 - val_accuracy: 0.8289 - val_loss: 0.5546 - learning_rate: 6.0000e-05
# Epoch 80/200
# 495/495 - 36s - 72ms/step - accuracy: 0.9030 - loss: 0.2822 - val_accuracy: 0.8329 - val_loss: 0.5492 - learning_rate: 6.0000e-05
# Epoch 81/200
# 495/495 - 37s - 75ms/step - accuracy: 0.9054 - loss: 0.2806 - val_accuracy: 0.8324 - val_loss: 0.5553 - learning_rate: 6.0000e-05
# Epoch 82/200
# 495/495 - 37s - 75ms/step - accuracy: 0.9076 - loss: 0.2729 - val_accuracy: 0.8310 - val_loss: 0.5502 - learning_rate: 6.0000e-05
# Epoch 83/200
# 495/495 - 37s - 75ms/step - accuracy: 0.9076 - loss: 0.2717 - val_accuracy: 0.8358 - val_loss: 0.5452 - learning_rate: 6.0000e-05
# Epoch 84/200
# 495/495 - 41s - 83ms/step - accuracy: 0.9084 - loss: 0.2709 - val_accuracy: 0.8297 - val_loss: 0.5631 - learning_rate: 6.0000e-05
# Epoch 85/200
# 495/495 - 37s - 76ms/step - accuracy: 0.9069 - loss: 0.2734 - val_accuracy: 0.8318 - val_loss: 0.5501 - learning_rate: 6.0000e-05
# Epoch 86/200
# 495/495 - 36s - 72ms/step - accuracy: 0.9086 - loss: 0.2672 - val_accuracy: 0.8292 - val_loss: 0.5620 - learning_rate: 6.0000e-05
# Epoch 87/200
# 495/495 - 39s - 78ms/step - accuracy: 0.9055 - loss: 0.2751 - val_accuracy: 0.8313 - val_loss: 0.5529 - learning_rate: 6.0000e-05
# Epoch 88/200
# 495/495 - 40s - 81ms/step - accuracy: 0.9081 - loss: 0.2696 - val_accuracy: 0.8316 - val_loss: 0.5542 - learning_rate: 6.0000e-05
# Epoch 89/200
# 495/495 - 40s - 80ms/step - accuracy: 0.9106 - loss: 0.2598 - val_accuracy: 0.8326 - val_loss: 0.5504 - learning_rate: 1.2000e-05
# Epoch 90/200
# 495/495 - 37s - 74ms/step - accuracy: 0.9107 - loss: 0.2644 - val_accuracy: 0.8353 - val_loss: 0.5493 - learning_rate: 1.2000e-05
# Epoch 91/200
# 495/495 - 39s - 78ms/step - accuracy: 0.9089 - loss: 0.2638 - val_accuracy: 0.8340 - val_loss: 0.5520 - learning_rate: 1.2000e-05
# Epoch 92/200
# 495/495 - 38s - 78ms/step - accuracy: 0.9133 - loss: 0.2574 - val_accuracy: 0.8345 - val_loss: 0.5495 - learning_rate: 1.2000e-05
# Epoch 93/200
# 495/495 - 39s - 78ms/step - accuracy: 0.9105 - loss: 0.2596 - val_accuracy: 0.8348 - val_loss: 0.5505 - learning_rate: 1.2000e-05
# Epoch 94/200
# 495/495 - 37s - 76ms/step - accuracy: 0.9135 - loss: 0.2579 - val_accuracy: 0.8345 - val_loss: 0.5513 - learning_rate: 2.4000e-06
# Epoch 95/200
# 495/495 - 37s - 75ms/step - accuracy: 0.9124 - loss: 0.2553 - val_accuracy: 0.8332 - val_loss: 0.5493 - learning_rate: 2.4000e-06
# Epoch 96/200
# 495/495 - 41s - 83ms/step - accuracy: 0.9121 - loss: 0.2566 - val_accuracy: 0.8340 - val_loss: 0.5491 - learning_rate: 2.4000e-06
# Epoch 97/200
# 495/495 - 36s - 73ms/step - accuracy: 0.9111 - loss: 0.2608 - val_accuracy: 0.8326 - val_loss: 0.5492 - learning_rate: 2.4000e-06
# Epoch 98/200
# 495/495 - 42s - 85ms/step - accuracy: 0.9086 - loss: 0.2639 - val_accuracy: 0.8345 - val_loss: 0.5491 - learning_rate: 2.4000e-06
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8430 - loss: 0.5412
#
# Test Loss: 0.5452
# Test Accuracy: 0.8358
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      browsing       0.94      0.92      0.93       500
#          chat       0.60      0.63      0.62       178
#            ft       0.75      0.77      0.76       204
#          mail       0.51      0.70      0.59        50
#           p2p       0.90      0.94      0.92       200
#     streaming       0.70      0.76      0.73        96
#          voip       0.99      1.00      1.00       565
#  vpn-browsing       0.79      0.70      0.74       500
#      vpn-chat       0.56      0.66      0.61       239
#        vpn-ft       0.76      0.67      0.71       387
#      vpn-mail       0.68      0.71      0.70        98
#       vpn-p2p       0.97      0.97      0.97       186
# vpn-streaming       0.79      0.86      0.82        95
#      vpn-voip       0.98      0.97      0.98       454
#
#      accuracy                           0.84      3752
#     macro avg       0.78      0.81      0.79      3752
#  weighted avg       0.84      0.84      0.84      3752

# %%
import joblib

joblib.dump(xgb_model, "xgboost_vpn_modell.pkl")
# Out:
# ['xgboost_vpn_modell.pkl']

# %%
import joblib

# %%
# Save CNN model
cnn_model.save("cnn_vpnnnn_model.h5")

# Save scaler (required for CNN)
import joblib
joblib.dump(scaler, "scaler.pkl")

# Save label encoder
joblib.dump(le, "label_encoder.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['label_encoder.pkl']

# %%
import gradio as gr
import numpy as np
import joblib

# ------------------------------
# Load saved XGBoost model
# ------------------------------
xgb_model = joblib.load("/content/xgboost_vpn_modell.pkl")
label_encoder = joblib.load("/content/label_encoder.pkl")

# ------------------------------
# Feature order (MUST match training)
# ------------------------------
feature_order = [
    "duration",
    "min_fiat","mean_fiat","max_fiat",
    "min_biat","mean_biat","max_biat",
    "min_flowiat","mean_flowiat","max_flowiat","std_flowiat",
    "flowPktsPerSecond","flowBytesPerSecond",
    "min_active","mean_active","max_active","std_active",
    "min_idle","mean_idle","max_idle","std_idle",
    "total_fiat","total_biat"
]

# ------------------------------
# Prediction function
# ------------------------------
def predict_xgboost(*features):
    X = np.array(features).reshape(1, -1)
    pred = xgb_model.predict(X)[0]
    return label_encoder.inverse_transform([pred])[0]

# ------------------------------
# Gradio Interface
# ------------------------------
inputs = []
for feat in feature_order:
    inputs.append(gr.Number(label=feat))

iface = gr.Interface(
    fn=predict_xgboost,
    inputs=inputs,
    outputs=gr.Textbox(label="Predicted Traffic Type"),
    title="VPN vs Non-VPN Classification (XGBoost)",
    description="XGBoost-based network traffic classification using flow-level features"
)

iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d94e9a3b8b94d14d5c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d94e9a3b8b94d14d5c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
